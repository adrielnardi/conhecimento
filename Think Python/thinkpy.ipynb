# %% [markdown]
# #Conceitos:
#
# ##Python
# - Linguagem de Programação de alto nível
# - Portáveis ( os códigos são aproveitados, não precisam ser reescritos)
# - Linguagem Interpretada: linha de comando(terminal) ou script(arquivo .py)

# %% [markdown]
# ###**Processar Alto nível e Traduzir Baixo nível:**
#
# 1) **Intepretador**:lê o código fonte e interpreta linha a linha para linguagem de baixo nível

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2) **Compilador:** lê o código fonte e traduz em código objeto(executável). Uma vez compilado, pode ser executado repetidamente, sem que precise de uma tradução.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ler oq é um programa até o glosário
#
# copiar o glosário linha a linha
#
# gerar novo pdf
